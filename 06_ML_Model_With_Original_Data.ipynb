# %%
import pandas as pd
import spacy
nlp = spacy.load("en_core_web_sm")
from spacy.lang.en.stop_words import STOP_WORDS

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics import classification_report,precision_recall_curve, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

from sklearn.model_selection import GridSearchCV

from collections import Counter
import itertools
import operator
import numpy as np
from matplotlib import pyplot as plt

# %%
def get_normalized_strings(x):
    doc = nlp(x, disable=["parser", "ner"])
    lemma = [token.lemma_ for token in doc]
    text = [lemma_i for lemma_i in lemma if (lemma_i not in STOP_WORDS and 
                                             not lemma_i.isdigit() and 
                                             lemma_i.isalnum() and 
                                             len(lemma_i)> 1)]
    text = " ".join(text)
    return text

# %%
train_data = pd.read_csv("data_v2/train_data.csv", usecols=["reviewText", "sentiment"])
val_data = pd.read_csv("data_v2/validation_data.csv", usecols=["reviewText", "sentiment"])
train_data = pd.concat([train_data, val_data], ignore_index=True)
train_data.dropna(inplace=True)

train_data["text"] = train_data["reviewText"].apply(lambda x: get_normalized_strings(x.lower().strip()))
train_data = train_data.sample(frac=1)

# %%
test_data = pd.read_csv("data_v2/test_data.csv", usecols=["reviewText", "sentiment"])

test_data.dropna(inplace=True)

test_data["text"] = test_data["reviewText"].apply(lambda x: get_normalized_strings(x.lower().strip()))

# %%
train_X = train_data["text"].to_list()
train_y = train_data["sentiment"].values

test_X = test_data["text"].to_list()
test_y = test_data["sentiment"].values

# %%
all_words = [x.split() for x in train_X]
all_words = list(itertools.chain.from_iterable(all_words))
word_distribution = Counter(all_words)
word_distribution = dict(sorted(word_distribution.items(), key=operator.itemgetter(1), reverse=True))

# %%
word_distribution
# Out:
# {'card': 4377,
#  'work': 2251,
#  'use': 1742,
#  'phone': 1526,
#  'gb': 1400,
#  'great': 1196,
#  'buy': 1135,
#  'memory': 1092,
#  'sandisk': 1065,
#  'fast': 953,
#  'sd': 932,
#  'good': 858,
#  'galaxy': 815,
#  'price': 771,
#  'speed': 712,
#  'samsung': 671,
#  'problem': 666,
#  'storage': 610,
#  'tablet': 594,
#  'need': 594,
#  'video': 590,
#  'product': 574,
#  'format': 521,
#  'camera': 516,
#  'music': 511,
#  'issue': 491,
#  'device': 483,
#  'class': 474,
#  'micro': 455,
#  'purchase': 442,
#  'read': 429,
#  'like': 421,
#  'transfer': 416,
#  'recommend': 415,
#  'time': 412,
#  'file': 412,
#  'write': 397,
#  'adapter': 396,
#  'note': 395,
#  'space': 386,
#  'come': 373,
#  'new': 359,
#  'picture': 343,
#  'lot': 333,
#  'store': 316,
#  'amazon': 316,
#  'far': 315,
#  'datum': 295,
#  'microsd': 290,
#  'fine': 281,
#  'gopro': 275,
#  'month': 271,
#  'brand': 271,
#  'movie': 265,
#  'want': 260,
#  's3': 254,
#  'computer': 247,
#  'try': 245,
#  'photo': 242,
#  's4': 229,
#  'think': 227,
#  'capacity': 218,
#  'know': 218,
#  'perfectly': 216,
#  'android': 214,
#  'recognize': 208,
#  'quality': 208,
#  'little': 198,
#  'thing': 198,
#  'ultra': 192,
#  'high': 192,
#  'find': 189,
#  'run': 183,
#  'love': 180,
#  'review': 179,
#  'expect': 178,
#  'size': 177,
#  'day': 174,
#  'old': 174,
#  'hold': 173,
#  'happy': 171,
#  'app': 169,
#  'easy': 168,
#  'small': 168,
#  'right': 163,
#  'hd': 163,
#  'pro': 161,
#  'reliable': 160,
#  'cheap': 160,
#  'look': 160,
#  'instal': 157,
#  'perfect': 156,
#  'long': 154,
#  'large': 153,
#  'extra': 152,
#  'able': 152,
#  'add': 151,
#  'sure': 151,
#  'order': 150,
#  'test': 148,
#  'year': 147,
#  'fail': 146,
#  'lose': 145,
#  'mb': 143,
#  'play': 142,
#  'fit': 141,
#  'item': 137,
#  'reader': 137,
#  'record': 137,
#  'way': 135,
#  'highly': 133,
#  'plenty': 132,
#  'bad': 129,
#  'copy': 128,
#  'pc': 127,
#  'usb': 125,
#  'fat32': 124,
#  'nice': 123,
#  'excellent': 122,
#  'deal': 121,
#  'surface': 119,
#  'drive': 117,
#  'free': 117,
#  'disk': 116,
#  'packaging': 116,
#  'tab': 115,
#  'start': 115,
#  'return': 114,
#  'room': 114,
#  'big': 113,
#  'support': 113,
#  'plug': 112,
#  'replace': 112,
#  'smartphone': 111,
#  'download': 111,
#  'load': 109,
#  'allow': 107,
#  'slow': 106,
#  'laptop': 105,
#  'black': 105,
#  'rate': 103,
#  'different': 102,
#  'quickly': 101,
#  'save': 101,
#  'cell': 101,
#  'pretty': 99,
#  'star': 99,
#  'microsdhc': 99,
#  'version': 98,
#  'error': 98,
#  'hero': 98,
#  'performance': 98,
#  'arrive': 95,
#  'chip': 95,
#  'update': 95,
#  'quick': 95,
#  'gig': 94,
#  'pay': 94,
#  'exactly': 94,
#  'second': 94,
#  'worth': 93,
#  'hard': 92,
#  'sdhc': 89,
#  'definitely': 89,
#  'replacement': 87,
#  'thank': 87,
#  'upgrade': 87,
#  'complaint': 87,
#  'money': 86,
#  'week': 86,
#  'flawlessly': 86,
#  'flash': 86,
#  'etc': 85,
#  'experience': 85,
#  'stuff': 85,
#  'slot': 84,
#  'window': 84,
#  'receive': 83,
#  'available': 83,
#  'perform': 83,
#  'hour': 83,
#  'super': 82,
#  'expand': 81,
#  'player': 81,
#  'ton': 81,
#  'pop': 80,
#  'suppose': 79,
#  'include': 79,
#  'tell': 79,
#  'package': 78,
#  'insert': 78,
#  'send': 77,
#  'stop': 77,
#  'low': 77,
#  'fill': 77,
#  'mp3': 75,
#  'case': 75,
#  'couple': 73,
#  'remove': 72,
#  'medium': 70,
#  'wrong': 70,
#  'internal': 69,
#  'people': 69,
#  'actually': 68,
#  'ii': 68,
#  'compatible': 67,
#  'bit': 67,
#  'awesome': 67,
#  'standard': 67,
#  'worry': 67,
#  'smart': 66,
#  'shipping': 66,
#  'recording': 66,
#  'shoot': 66,
#  'wife': 65,
#  'asus': 64,
#  '1080p': 64,
#  'job': 64,
#  'digital': 64,
#  'provide': 63,
#  'trust': 63,
#  'instead': 63,
#  'die': 63,
#  'let': 62,
#  'sale': 62,
#  'reason': 62,
#  'ship': 61,
#  'exfat': 61,
#  'mean': 61,
#  'notice': 61,
#  'install': 60,
#  'wait': 60,
#  'difference': 60,
#  'cam': 60,
#  'sdxc': 59,
#  'place': 59,
#  'box': 58,
#  'mobile': 58,
#  'cost': 58,
#  'away': 58,
#  'pic': 57,
#  'warranty': 57,
#  'drop': 57,
#  'probably': 56,
#  'ask': 56,
#  'value': 56,
#  'song': 56,
#  'edition': 56,
#  'leave': 56,
#  'watch': 55,
#  'turn': 55,
#  'access': 55,
#  'microsdxc': 55,
#  'hero3': 54,
#  'number': 54,
#  'stick': 54,
#  'customer': 54,
#  'immediately': 53,
#  'system': 53,
#  'pleased': 53,
#  'lag': 53,
#  'rating': 53,
#  'reformatte': 53,
#  'point': 53,
#  'require': 52,
#  'htc': 52,
#  'amazing': 51,
#  'unit': 51,
#  'easily': 50,
#  'regular': 49,
#  'end': 49,
#  'minute': 49,
#  'san': 48,
#  'beat': 48,
#  'finally': 48,
#  'wish': 48,
#  'fix': 48,
#  'soon': 48,
#  'happen': 47,
#  'mount': 47,
#  'service': 47,
#  'sony': 47,
#  'change': 47,
#  'maybe': 47,
#  'reformat': 47,
#  'advertised': 47,
#  'real': 46,
#  'information': 46,
#  'increase': 46,
#  'ago': 46,
#  'hope': 46,
#  'check': 45,
#  'later': 45,
#  'game': 45,
#  'sec': 44,
#  'contact': 44,
#  'believe': 44,
#  'past': 44,
#  'backup': 44,
#  'program': 44,
#  'application': 44,
#  'tiny': 44,
#  'company': 44,
#  'build': 43,
#  'especially': 43,
#  'external': 43,
#  'decide': 43,
#  'glad': 42,
#  'plus': 42,
#  'usually': 42,
#  'additional': 42,
#  'expensive': 42,
#  'uhs': 42,
#  'model': 42,
#  'corrupt': 42,
#  'compare': 41,
#  'friend': 41,
#  'feel': 41,
#  'canon': 41,
#  'rt': 41,
#  'describe': 40,
#  'offer': 40,
#  'sell': 40,
#  'half': 40,
#  'satisfied': 40,
#  'option': 40,
#  'huge': 40,
#  'failure': 39,
#  'action': 39,
#  'fact': 38,
#  'advertise': 38,
#  'pick': 38,
#  'handle': 38,
#  'delete': 38,
#  'collection': 38,
#  'extremely': 38,
#  'image': 38,
#  'simply': 38,
#  'defective': 37,
#  'word': 37,
#  'car': 37,
#  'nook': 37,
#  'user': 37,
#  'type': 37,
#  'result': 37,
#  'trouble': 37,
#  'open': 36,
#  'complain': 36,
#  'carry': 36,
#  'gps': 36,
#  'luck': 35,
#  'appear': 35,
#  'purpose': 35,
#  'entire': 35,
#  'cause': 35,
#  'directly': 35,
#  'buck': 35,
#  'software': 35,
#  'absolutely': 35,
#  'battery': 35,
#  'report': 35,
#  'guess': 34,
#  'yes': 34,
#  'ok': 34,
#  'help': 34,
#  'data': 34,
#  'important': 33,
#  'figure': 33,
#  'currently': 33,
#  'function': 33,
#  'solid': 33,
#  'droid': 33,
#  'microsoft': 33,
#  'spend': 33,
#  'zero': 33,
#  'consider': 32,
#  'charm': 32,
#  'double': 32,
#  'decent': 32,
#  'rom': 32,
#  'research': 32,
#  'line': 32,
#  'today': 31,
#  'original': 31,
#  'dash': 31,
#  'electronic': 31,
#  'document': 31,
#  'reliability': 31,
#  'previous': 31,
#  'message': 31,
#  'completely': 31,
#  'connect': 30,
#  'retail': 30,
#  '30mb': 30,
#  'charge': 30,
#  'google': 30,
#  'online': 30,
#  'manufacturer': 30,
#  'reasonable': 29,
#  'boot': 29,
#  'whatsoever': 29,
#  'short': 29,
#  'addition': 29,
#  'state': 29,
#  'writing': 29,
#  's5': 29,
#  'ready': 29,
#  'recently': 29,
#  'kb': 29,
#  'windows': 28,
#  'ssd': 28,
#  'technology': 28,
#  'trip': 28,
#  'content': 28,
#  'continue': 28,
#  'dslr': 28,
#  'extreme': 28,
#  'frustration': 28,
#  'design': 28,
#  'prime': 27,
#  'process': 27,
#  'power': 27,
#  'date': 27,
#  'lg': 27,
#  'library': 27,
#  'close': 27,
#  'delay': 27,
#  'set': 27,
#  'waste': 27,
#  'limit': 27,
#  'search': 27,
#  'capture': 27,
#  'multiple': 27,
#  'mac': 27,
#  'setting': 27,
#  'simple': 26,
#  'deliver': 26,
#  'total': 26,
#  'comment': 26,
#  'instantly': 26,
#  'suggest': 26,
#  'son': 26,
#  'fault': 26,
#  'future': 26,
#  'razr': 26,
#  'partition': 26,
#  'kind': 26,
#  'adaptor': 26,
#  'map': 26,
#  'hassle': 25,
#  'book': 25,
#  'evo': 25,
#  'course': 25,
#  'unmount': 25,
#  'gs4': 25,
#  'spec': 25,
#  'randomly': 25,
#  'swap': 25,
#  'delivery': 24,
#  'kid': 24,
#  'guy': 24,
#  'normal': 24,
#  'pull': 24,
#  'life': 24,
#  'matter': 24,
#  'break': 24,
#  'iii': 24,
#  'actual': 24,
#  'claim': 24,
#  'choose': 24,
#  'folder': 24,
#  's2': 23,
#  'tech': 23,
#  'dell': 23,
#  'anymore': 23,
#  'cellphone': 23,
#  'seller': 23,
#  'market': 23,
#  'average': 23,
#  'plastic': 23,
#  'miss': 23,
#  'cloud': 23,
#  'similar': 23,
#  'early': 23,
#  'reading': 23,
#  'mode': 23,
#  'chance': 23,
#  'switch': 23,
#  'os': 23,
#  'hot': 23,
#  'motorola': 23,
#  'formatting': 23,
#  'gs3': 23,
#  'accept': 23,
#  'nokia': 23,
#  'port': 23,
#  'ntfs': 23,
#  'venue': 23,
#  'playback': 22,
#  'max': 22,
#  'bunch': 22,
#  'maximum': 22,
#  'shot': 22,
#  'transformer': 22,
#  'fat': 22,
#  'compatibility': 22,
#  'frame': 22,
#  'verizon': 22,
#  'throw': 22,
#  'meet': 22,
#  'handy': 22,
#  'hand': 22,
#  'realize': 22,
#  'home': 22,
#  'remember': 22,
#  'single': 22,
#  'piece': 22,
#  'possible': 22,
#  'stock': 22,
#  'restart': 22,
#  'damage': 22,
#  'siii': 21,
#  'list': 21,
#  'base': 21,
#  'garmin': 21,
#  'reboot': 21,
#  'period': 21,
#  'travel': 21,
#  'likely': 21,
#  'disc': 21,
#  'mini': 21,
#  'dollar': 21,
#  'tv': 21,
#  'mention': 21,
#  'spare': 21,
#  'fake': 21,
#  'refund': 21,
#  'assume': 20,
#  'local': 20,
#  'intend': 20,
#  'info': 20,
#  'late': 20,
#  'disappoint': 20,
#  'iphone': 20,
#  'macbook': 20,
#  'capability': 20,
#  'totally': 20,
#  'linux': 20,
#  'solve': 20,
#  'promise': 20,
#  'unfortunately': 20,
#  'proof': 20,
#  'live': 20,
#  'lumia': 20,
#  'mind': 20,
#  'properly': 19,
#  'affordable': 19,
#  'usable': 19,
#  'forum': 19,
#  'batch': 19,
#  'stream': 19,
#  'bring': 19,
#  'current': 19,
#  'gift': 19,
#  'color': 19,
#  'straight': 19,
#  'plan': 19,
#  'non': 19,
#  'overall': 18,
#  'c10': 18,
#  'sansa': 18,
#  'film': 18,
#  'recorder': 18,
#  'loss': 18,
#  'inside': 18,
#  'daughter': 18,
#  'fair': 18,
#  'screen': 18,
#  'transcend': 18,
#  'benchmark': 18,
#  'stay': 18,
#  'lifetime': 18,
#  'sized': 18,
#  'resolution': 18,
#  'freeze': 18,
#  'lte': 18,
#  'create': 18,
#  'thousand': 18,
#  'specifically': 18,
#  'kingston': 18,
#  'moment': 18,
#  'cover': 17,
#  'certain': 17,
#  'solution': 17,
#  'camcorder': 17,
#  'desktop': 17,
#  'definition': 17,
#  'site': 17,
#  'snap': 17,
#  'true': 17,
#  'choice': 17,
#  'useful': 17,
#  'scan': 17,
#  'capable': 17,
#  'detect': 17,
#  'confirm': 17,
#  'fully': 17,
#  'reasonably': 17,
#  'stand': 17,
#  'glitch': 17,
#  'thumb': 17,
#  'speedy': 17,
#  'counterfeit': 17,
#  'oh': 17,
#  'post': 17,
#  'expansion': 17,
#  'hear': 17,
#  'flawless': 17,
#  'manufacture': 17,
#  'ability': 17,
#  'family': 17,
#  'disappointed': 17,
#  'da': 17,
#  'crash': 16,
#  'unable': 16,
#  'smooth': 16,
#  'xc': 16,
#  'lock': 16,
#  'wonder': 16,
#  'uhs1': 16,
#  'machine': 16,
#  'description': 16,
#  'dead': 16,
#  'begin': 16,
#  'eventually': 16,
#  'fall': 16,
#  'cd': 16,
#  'fantastic': 16,
#  'generic': 16,
#  'necessary': 16,
#  'speak': 16,
#  'exception': 16,
#  'inexpensive': 16,
#  'minimum': 16,
#  'hit': 16,
#  'vacation': 16,
#  'special': 16,
#  'email': 15,
#  'installation': 15,
#  'lenovo': 15,
#  'view': 15,
#  'internet': 15,
#  'rma': 15,
#  'usual': 15,
#  'baby': 15,
#  'care': 15,
#  'sit': 15,
#  '10mb': 15,
#  'incredible': 15,
#  'automatically': 15,
#  'hopefully': 15,
#  'originally': 15,
#  '4k': 15,
#  'scandisk': 15,
#  'red': 15,
#  'extend': 15,
#  'enjoy': 15,
#  'wonderful': 15,
#  'fan': 15,
#  'nicely': 15,
#  'reputable': 15,
#  'envelope': 15,
#  'default': 15,
#  'prefer': 15,
#  'listen': 15,
#  'ipod': 15,
#  'hc': 15,
#  'nikon': 15,
#  'air': 15,
#  'twice': 14,
#  'cool': 14,
#  'optimus': 14,
#  'tool': 14,
#  'audio': 14,
#  'form': 14,
#  'learn': 14,
#  'upload': 14,
#  'fairly': 14,
#  'friday': 14,
#  'hesitate': 14,
#  'specific': 14,
#  'clip': 14,
#  'pad': 14,
#  'count': 14,
#  'term': 14,
#  'burst': 14,
#  'forget': 14,
#  'click': 14,
#  'crap': 14,
#  'question': 14,
#  'consistently': 14,
#  'compact': 14,
#  'crazy': 14,
#  'usage': 14,
#  'expectation': 14,
#  'avoid': 14,
#  'vs': 14,
#  'website': 14,
#  'common': 14,
#  'recover': 14,
#  'genuine': 14,
#  'attempt': 14,
#  'indicate': 13,
#  'person': 13,
#  'tf700': 13,
#  'secure': 13,
#  'basically': 13,
#  'range': 13,
#  'alot': 13,
#  'regret': 13,
#  'cable': 13,
#  'act': 13,
#  'overkill': 13,
#  'display': 13,
#  'recovery': 13,
#  'unmounte': 13,
#  'protect': 13,
#  'safe': 13,
#  'root': 13,
#  'complete': 13,
#  'example': 13,
#  'apple': 13,
#  'brainer': 13,
#  'sorry': 13,
#  'firmware': 13,
#  'portable': 13,
#  'prove': 13,
#  'daily': 13,
#  'maxx': 13,
#  'negative': 13,
#  'aware': 13,
#  'strong': 13,
#  'exist': 13,
#  'advantage': 13,
#  'vendor': 13,
#  'def': 13,
#  'smoothly': 13,
#  'corruption': 12,
#  'operate': 12,
#  'serve': 12,
#  'dashcam': 12,
#  'main': 12,
#  'xperia': 12,
#  'christmas': 12,
#  'technical': 12,
#  'exchange': 12,
#  'premium': 12,
#  'apparently': 12,
#  'clear': 12,
#  'pi': 12,
#  'contour': 12,
#  'mail': 12,
#  'finger': 12,
#  'jump': 12,
#  'durable': 12,
#  'bargain': 12,
#  'stable': 12,
#  'pack': 12,
#  'stutter': 12,
#  'certainly': 12,
#  'length': 12,
#  'accord': 12,
#  'previously': 12,
#  'feature': 12,
#  'boost': 12,
#  'blackberry': 12,
#  'link': 12,
#  'correctly': 12,
#  'particular': 12,
#  'helpful': 12,
#  'initially': 12,
#  'supply': 12,
#  'remain': 12,
#  'hiccup': 12,
#  'enable': 12,
#  'utility': 12,
#  'board': 12,
#  'gbs': 12,
#  'bill': 12,
#  'normally': 12,
#  'steal': 12,
#  'pny': 12,
#  'dd': 12,
#  'psp': 12,
#  'raw': 12,
#  'champ': 12,
#  'unreadable': 11,
#  'dud': 11,
#  'rest': 11,
#  'minor': 11,
#  'photography': 11,
#  'raspberry': 11,
#  'constantly': 11,
#  'amazed': 11,
#  'seamlessly': 11,
#  'nearly': 11,
#  'imagine': 11,
#  'careful': 11,
#  'doc': 11,
#  'silver': 11,
#  'prior': 11,
#  'suddenly': 11,
#  'dozen': 11,
#  'track': 11,
#  'u46a': 11,
#  'easeus': 11,
#  'pre': 11,
#  'factor': 11,
#  'morning': 11,
#  'z10': 11,
#  'suck': 11,
#  'master': 11,
#  'itune': 11,
#  'footage': 11,
#  'rip': 11,
#  'inch': 11,
#  'slide': 11,
#  'warning': 11,
#  'understand': 11,
#  'regard': 11,
#  'forever': 11,
#  'affp': 11,
#  'exfat32': 11,
#  'match': 11,
#  'surprised': 11,
#  'ex': 11,
#  'lexar': 11,
#  'manager': 11,
#  'manage': 10,
#  'measure': 10,
#  'encounter': 10,
#  'condition': 10,
#  'tend': 10,
#  'retailer': 10,
#  'random': 10,
#  'unlike': 10,
#  'concern': 10,
#  'operation': 10,
#  'mainly': 10,
#  'frequently': 10,
#  'sdcard': 10,
#  'correct': 10,
#  'answer': 10,
#  'till': 10,
#  'worried': 10,
#  'response': 10,
#  'heavy': 10,
#  'surprise': 10,
#  'hitch': 10,
#  'reviewer': 10,
#  'select': 10,
#  'party': 10,
#  'touch': 10,
#  'honestly': 10,
#  'lol': 10,
#  'ray': 10,
#  'serial': 10,
#  'convert': 10,
#  'exact': 10,
#  'instruction': 10,
#  'ms': 10,
#  'erase': 10,
#  '720p': 10,
#  'discover': 10,
#  'fortunately': 10,
#  'source': 10,
#  'confident': 10,
#  'ebay': 10,
#  'blank': 10,
#  'share': 10,
#  'truly': 10,
#  'notification': 10,
#  'block': 10,
#  'sandisc': 10,
#  'hardware': 10,
#  'byte': 10,
#  'idea': 10,
#  'minidrive': 10,
#  'appreciate': 10,
#  'dependable': 10,
#  'hi': 10,
#  'factory': 10,
#  'reset': 10,
#  'min': 9,
#  'discount': 9,
#  'operating': 9,
#  '32gig': 9,
#  'spot': 9,
#  'taking': 9,
#  'skip': 9,
#  'prompt': 9,
#  'pair': 9,
#  '60fps': 9,
#  'hate': 9,
#  'awhile': 9,
#  'ect': 9,
#  'converter': 9,
#  'custom': 9,
#  'copying': 9,
#  'acer': 9,
#  'pricing': 9,
#  'shop': 9,
#  'ahead': 9,
#  'benefit': 9,
#  'greatly': 9,
#  'protune': 9,
#  'initial': 9,
#  'wireless': 9,
#  'refuse': 9,
#  'album': 9,
#  'finish': 9,
#  'direct': 9,
#  'beware': 9,
#  'loading': 9,
#  'waterproof': 9,
#  'sport': 9,
#  'limited': 9,
#  'remount': 9,
#  'doubt': 9,
#  'eye': 9,
#  'water': 9,
#  'area': 9,
#  'requirement': 9,
#  'mbps': 9,
#  'series': 9,
#  'disappointing': 9,
#  'forward': 9,
#  'reach': 9,
#  'ride': 9,
#  'odd': 9,
#  'separate': 9,
#  'dual': 9,
#  'processor': 9,
#  'mistake': 9,
#  '3rd': 9,
#  'primary': 9,
#  'fingernail': 9,
#  'promptly': 9,
#  'mp': 9,
#  'improve': 9,
#  'project': 9,
#  'outside': 9,
#  'white': 9,
#  'success': 9,
#  'sii': 9,
#  'valuable': 9,
#  'formatted': 9,
#  'disappear': 9,
#  'road': 9,
#  'okay': 9,
#  'rock': 9,
#  'yesterday': 9,
#  'dropbox': 9,
#  'occur': 9,
#  'srandom': 9,
#  'luckily': 9,
#  'control': 9,
#  'sense': 9,
#  'massive': 9,
#  'positive': 9,
#  'utilize': 9,
#  'acceptable': 9,
#  'heat': 9,
#  'unexpectedly': 9,
#  'authentic': 9,
#  'relate': 8,
#  'driver': 8,
#  'pass': 8,
#  'processing': 8,
#  'sprint': 8,
#  'middle': 8,
#  'typical': 8,
#  'professional': 8,
#  'transferring': 8,
#  'girlfriend': 8,
#  'variety': 8,
#  'world': 8,
#  'kinda': 8,
#  'flexibility': 8,
#  'story': 8,
#  'zip': 8,
#  'bright': 8,
#  'removable': 8,
#  'helmet': 8,
#  'primarily': 8,
#  'wow': 8,
#  'note2': 8,
#  'wifi': 8,
#  'ideal': 8,
#  'respond': 8,
#  ...}

# %%
tfidf=TfidfVectorizer(max_df=0.90, min_df=2,
                      max_features=2500, lowercase=True, 
                      stop_words='english', 
                      preprocessor=None
                      )

countvectorizer = CountVectorizer(max_df=0.90, min_df=2,
                                  max_features=2500, lowercase=True, 
                                  stop_words='english', 
                                  preprocessor=None)

# %%
# %%time

train_tfidf=tfidf.fit_transform(train_X)
train_cvec=countvectorizer.fit_transform(train_X)
# Out:
# CPU times: user 82.5 ms, sys: 2.61 ms, total: 85.1 ms
# Wall time: 84.1 ms

# %%
test_tfidf=tfidf.transform(test_X)
test_cvec=countvectorizer.transform(test_X)

# %%
def f1_score_manual(y, y_pred):
    tp = 0
    fp = 0
    tn = 0
    fn = 0
    for actual_value, predicted_value in zip(y, y_pred):
        if predicted_value == actual_value:  # t?
            if predicted_value:  # tp
                tp += 1
            else:  # tn
                tn += 1
        else:  # f?
            if predicted_value:  # fp
                fp += 1
            else:  # fn
                fn += 1

    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1 = 2 * precision * recall / (precision + recall)

    print('----------------------------------')
    print('                 Actual Value')
    print('----------------------------------')
    print(f'            Positive    Negative')
    print(f'Positive    {tp:^8}    {fp:^8}')
    print(f'Negative    {fn:^8}    {tn:^8}')
    print('----------------------------------')
    return f1

# %%
def get_best_threshold_by_f1(y_true, y_pred, thresholds):
    best_score = -1
    best_threshold=-1
    
    for th in thresholds:
        y_pred_label = [int(yi>=th) for yi in y_pred]
        score = f1_score(y_true, y_pred_label, average="macro")
        if score > best_score:
            best_score = score
            best_threshold = th
    
    return best_threshold, best_score

# %%
lr_model = LogisticRegression(max_iter=1000, random_state=0)
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)

grid_search = GridSearchCV(estimator=lr_model, param_grid=grid,
                           n_jobs=-1, cv=5,
                           scoring='f1', refit=True,
                           verbose=3)

grid_result = grid_search.fit(train_tfidf, train_y)

print("Optimal set of Parameters: {}".format(grid_result.best_params_))

lr_model = LogisticRegression(max_iter=1000, random_state=0, **grid_result.best_params_)
lr_model.fit(train_tfidf, train_y)
train_proba_lr = lr_model.predict_proba(train_tfidf)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# Optimal set of Parameters: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
train_proba_lr = train_proba_lr[:,1]
precision, recall, thresholds = precision_recall_curve(train_y, train_proba_lr)
best_threshold_lr, best_score_lr = get_best_threshold_by_f1(train_y, train_proba_lr, thresholds)

# %%
test_proba_lr = lr_model.predict_proba(test_tfidf)
test_proba_lr = test_proba_lr[:,1]
test_predict_labels_lr = [int(x>=best_threshold_lr) for x in test_proba_lr]


f1_score_manual(test_y, test_predict_labels_lr)
print(classification_report(test_y, test_predict_labels_lr))
# Out:
# ----------------------------------
#                  Actual Value
# ----------------------------------
#             Positive    Negative
# Positive      381          17
# Negative       12          29
# ----------------------------------
#               precision    recall  f1-score   support
#
#            0       0.71      0.63      0.67        46
#            1       0.96      0.97      0.96       393
#
#     accuracy                           0.93       439
#    macro avg       0.83      0.80      0.82       439
# weighted avg       0.93      0.93      0.93       439

# %%
dt_model = DecisionTreeClassifier(random_state=0)
criterion = ['gini', 'entropy']
max_depth = list(range(2,21,2))
max_features = ["sqrt", "log2"]

# define grid search
grid = dict(criterion=criterion, max_depth=max_depth, max_features=max_features)

grid_search = GridSearchCV(estimator=dt_model, param_grid=grid,
                           n_jobs=-1, cv=5,
                           scoring='f1', refit=True,
                           verbose=3)

grid_result = grid_search.fit(train_cvec, train_y)

print("Optimal set of Parameters: {}".format(grid_result.best_params_))

dt_model = DecisionTreeClassifier(random_state=0, **grid_result.best_params_)
dt_model.fit(train_cvec, train_y)
train_proba_dt = dt_model.predict_proba(train_cvec)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# Optimal set of Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt'}

# %%
train_proba_dt = train_proba_dt[:,1]
precision, recall, thresholds = precision_recall_curve(train_y, train_proba_dt)
best_threshold_dt, best_score_dt = get_best_threshold_by_f1(train_y, train_proba_dt, thresholds)

# %%
test_proba_dt = dt_model.predict_proba(test_cvec)
test_proba_dt = test_proba_dt[:,1]
test_predict_labels_dt = [int(x>=best_threshold_dt) for x in test_proba_dt]


f1_score_manual(test_y, test_predict_labels_dt)
print(classification_report(test_y, test_predict_labels_dt))
# Out:
# ----------------------------------
#                  Actual Value
# ----------------------------------
#             Positive    Negative
# Positive      374          23
# Negative       19          23
# ----------------------------------
#               precision    recall  f1-score   support
#
#            0       0.55      0.50      0.52        46
#            1       0.94      0.95      0.95       393
#
#     accuracy                           0.90       439
#    macro avg       0.74      0.73      0.73       439
# weighted avg       0.90      0.90      0.90       439

# %%
xg_model = XGBClassifier(objective= 'binary:logistic', nthread=4, seed=0, error_score='raise')

max_depth= [2, 3, 4, 5, 6, 7, 8, 9]
n_estimators= [50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 170, 180, 190, 200]
learning_rate= [0.1, 0.01, 0.05]


# define grid search
grid = dict(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate)

grid_search = GridSearchCV(estimator=xg_model, param_grid=grid,
                           n_jobs=-1, cv=5,
                           scoring='f1', refit=True,
                           verbose=True)

grid_result = grid_search.fit(train_tfidf, train_y)

print("Optimal set of Parameters: {}".format(grid_result.best_params_))

xg_model = XGBClassifier(objective= 'binary:logistic', nthread=4, seed=0, **grid_result.best_params_)
xg_model.fit(train_tfidf, train_y)
train_proba_xg = xg_model.predict_proba(train_tfidf)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [03:52:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "error_score" } are not used.
#
# Optimal set of Parameters: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 180}

# %%
train_proba_xg = train_proba_xg[:,1]
precision, recall, thresholds = precision_recall_curve(train_y, train_proba_xg)
best_threshold_xg, best_score_xg = get_best_threshold_by_f1(train_y, train_proba_xg, thresholds)

# %%
test_proba_xg = xg_model.predict_proba(test_tfidf)
test_proba_xg = test_proba_xg[:,1]
test_predict_labels_xg = [int(x>=best_threshold_xg) for x in test_proba_xg]


f1_score_manual(test_y, test_predict_labels_xg)
print(classification_report(test_y, test_predict_labels_xg))
# Out:
# ----------------------------------
#                  Actual Value
# ----------------------------------
#             Positive    Negative
# Positive      381          15
# Negative       12          31
# ----------------------------------
#               precision    recall  f1-score   support
#
#            0       0.72      0.67      0.70        46
#            1       0.96      0.97      0.97       393
#
#     accuracy                           0.94       439
#    macro avg       0.84      0.82      0.83       439
# weighted avg       0.94      0.94      0.94       439

# %%
best_threshold_xg
# Out:
# 0.7162392

# %%
features_importances = xg_model.feature_importances_
features_importances_indicies = np.argsort(features_importances)

feature_names = tfidf.get_feature_names_out()

top50_fetures = [feature_names[features_importances_indicies[i]] for i in range(-1, -51, -1)][::-1]
top50_feature_importances = [features_importances[features_importances_indicies[i]] for i in range(-1, -51, -1)][::-1]

# %%
plt.figure(figsize=(15, 12))

plt.barh(top50_fetures, top50_feature_importances)
plt.title("Most Important Words")
plt.tight_layout()
plt.show()
