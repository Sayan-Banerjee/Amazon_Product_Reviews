# %%
import pandas as pd
from transformers import pipeline
import spacy
import random
nlp = spacy.load("en_core_web_sm")

# %%
val_data = pd.read_csv("data_v2/validation_data.csv")

# %%
val_data["sentiment"].value_counts()
# Out:
# 1    392
# 0     47
# Name: sentiment, dtype: int64

# %%
unmasker_1 = pipeline("fill-mask", model="roberta-base")
unmasker_2 = pipeline("fill-mask", model="bert-base-cased")
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
val_data = val_data[val_data["sentiment"]==0]

# %%
val_data.shape
# Out:
# (47, 3)

# %%
def get_sents(x):
    for sent in nlp(x).sents:
        yield sent.text

# %%
def get_random_word_added_1(input_text):
    augmented_texts = []
    
    for sent in get_sents(input_text):
        orig_text_list = sent.split(" ")
        len_input = len(orig_text_list)
        if len_input > 3:
            rand_indx = random.randint(1, len_input-2)
            orig_text_list = orig_text_list[:rand_indx] + ["<mask>"] + orig_text_list[rand_indx:]
            new_text = " ".join(orig_text_list)
            augmented_text = unmasker_1(new_text)[0]['sequence']
            augmented_texts.append(augmented_text)
        else:
            augmented_texts.append(sent)
        
    text = ". ".join(augmented_texts)
    return text

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
def get_random_word_added_2(input_text):
    augmented_texts = []
    
    for sent in get_sents(input_text):
        orig_text_list = sent.split(" ")
        len_input = len(orig_text_list)
        if len_input > 3:
            rand_indx = random.randint(1, len_input-2)
            orig_text_list = orig_text_list[:rand_indx] + ["[MASK]"] + orig_text_list[rand_indx:]
            new_text = " ".join(orig_text_list)
            augmented_text = unmasker_2(new_text)[0]['sequence']
            augmented_texts.append(augmented_text)
        else:
            augmented_texts.append(sent)
        
    text = ". ".join(augmented_texts)
    return text

# %%
# %%time 

val_data["augmented_text_1"] = val_data["reviewText"].apply(lambda x: get_random_word_added_1(x))
# Out:
# CPU times: user 16.9 s, sys: 5.51 s, total: 22.4 s
# Wall time: 16.5 s

# %%
# %%time 

val_data["augmented_text_2"] = val_data["reviewText"].apply(lambda x: get_random_word_added_2(x))
# Out:
# CPU times: user 16 s, sys: 5.44 s, total: 21.4 s
# Wall time: 15.8 s

# %%
val_data
# Out:
#                                             reviewText  overall  sentiment  \
# 0    It's the wrong one because I thought I was get...      3.0          0
# 5    UPDATE:This card stopped working as of late Fe...      1.0          0
# 33   I do not know if the GS3's have issues with re...      3.0          0
# 37   Great little card.  The only problem I have ex...      3.0          0
# 54   Bought this card for my Galaxy S4 and after in...      2.0          0
# 59   But since I can't say with any certainty wheth...      3.0          0
# 61   Gave it 4 stars because I don't know if the pr...      3.0          0
# 65   SanDisk makes a lot of claims about this card ...      3.0          0
# 71   Doesn't work in my s2 skyrocket but works in m...      3.0          0
# 75   I connected it to my galaxy S4, but every now ...      3.0          0
# 79   Um nothing much to really say about it . The a...      3.0          0
# 83   I should have known better. Everyone is compla...      1.0          0
# 108  I bought this Sandisk 16GB Class 10 to use wit...      1.0          0
# 135  I ordered this memory card for my Drift Ghost-...      1.0          0
# 148  Hard to review this as the card arrived DOA. C...      2.0          0
# 153  Within an hour of using the memory card, it fa...      1.0          0
# 160  Pro:  &#9642;PriceCons:  &#9642;intially began...      1.0          0
# 161  I didn't  even have this card installed in my ...      1.0          0
# 182  Hello,Great card, great price. Plenty of speed...      1.0          0
# 183  Even though it says my review is for the 32gb ...      3.0          0
# 194  Fast card while it worked.  Died less than a w...      1.0          0
# 199  randomly erases all my data and asks me to for...      1.0          0
# 202  seems to work good in my gopro  have only had ...      3.0          0
# 209  SanDisk told me I needed to send this to them ...      2.0          0
# 216  This card only lasted two weeks before it bega...      1.0          0
# 239  I purchased four (4) items from amazon and whe...      1.0          0
# 255  Tried this with its adapter on DSLR Camera and...      2.0          0
# 257  Sandisk quality has failed me. Moving on to an...      2.0          0
# 263  this card would not show 64 GB until i spent $...      2.0          0
# 292  Died within 6 months! Stopped being able to re...      1.0          0
# 312  It works just like it should. It really does w...      3.0          0
# 320  Could not figure out why this card crashed mul...      1.0          0
# 321  Maybe I got a defective card but this one felt...      1.0          0
# 333  I bought two as a back up for my Gopro Hero 3....      2.0          0
# 343  THIS CARD DIED IN LESS THAN ONE MONTH IN MY SI...      1.0          0
# 351  the unit shows 0 bytes, in a PC or the phone. ...      1.0          0
# 354  This card continually unmounted in my S4. It w...      1.0          0
# 355  I hope you have better luck, it has gotten a l...      1.0          0
# 378  I ordered two 32GB and two 64Gb versions of th...      2.0          0
# 381  The product met my expectations (I expected it...      3.0          0
# 389  I got this card only a few months ago, used it...      1.0          0
# 390  Don't even waste your time buying this memory ...      1.0          0
# 391  I was really excited when this came out I have...      3.0          0
# 396  I loaded this memory card into my TF700T and c...      2.0          0
# 408  06.NOV.2012 - Bought the card.12.JAN.2014 - Ca...      1.0          0
# 426  Lasted about 8 months of daily use in my Andro...      3.0          0
# 430  I use it for my galaxy s4 and this card crashe...      3.0          0
#
#                                       augmented_text_1  \
# 0    It's the exact wrong one because I thought I w...
# 5    UPDATE:This card stopped working as of late Fe...
# 33   I do not know if the older GS3's have issues w...
# 37   Great little card..  The only problem I have e...
# 54   Bought this card for my Galaxy S4 and after in...
# 59   But since I can't say with any real certainty ...
# 61   Gave it 4 stars because I don't know if the re...
# 65   SanDisk makes a lot of claims about this card,...
# 71   Doesn't work in my s2x skyrocket but works in ...
# 75   I connected it to my galaxy S4, but only every...
# 79   Um nothing much more to really say about it.. ...
# 83   I probably should have known better.. Everyone...
# 108  I bought this Sandisk 16GB Class 10 to use wit...
# 135  I ordered this memory card for my Ford Drift G...
# 148  Hard to review all this as the card arrived DO...
# 153  Within an hour of using the memory card, it fa...
# 160  Pro:   &#9642;PriceCons:  &#9642;intially bega...
# 161  I didn't  even have this card installed in my ...
# 182  Hello,Great credit card, great price.. Plenty ...
# 183  Even though though it says my review is for th...
# 194  Fast card while doing it worked.. ... Died les...
# 199  randomly erases all my data and asks me to for...
# 202  seems to work good in my gopro  have only only...
# 209  SanDisk told me I needed to manually send this...
# 216  This particular card only lasted two weeks bef...
# 239  I purchased four (4) items from the amazon and...
# 255  Tried this with its adapter on DSLR Camera and...
# 257  Sandiskilling quality has failed me.. Moving o...
# 263  this card would not show 64 GB until i spent $...
# 292  Died within about 6 months!. Stopped being abl...
# 312  It all works just like it should.. It really d...
# 320  Could not figure out why, this card crashed mu...
# 321  Maybe I got a slightly defective card but this...
# 333  I bought two as a back up for my Gopro Hero 3....
# 343  THIS VIDEO CARD DIED IN LESS THAN ONE MONTH IN...
# 351  the unit shows 0 bytes, in a PC or on the phon...
# 354  This card continually unmounted in to my S4.. ...
# 355  I hope you have much better luck, it has gotte...
# 378  I ordered two 32GB and two 64Gb versions of th...
# 381  The final product met my expectations (I expec...
# 389  I got this card only a few short months ago, u...
# 390  Don't even waste all your time buying this mem...
# 391  I was really excited when this came out. I hav...
# 396  I loaded this memory card into my TF700T and I...
# 408  06.NOV.2012 -. Bought back the card.12.JAN.201...
# 426  Lasted about 8 months worth of daily use in my...
# 430  I use it for my galaxy and s4 and this card cr...
#
#                                       augmented_text_2
# 0    It's the wrong one because I thought I was get...
# 5    UPDATE : This smart card stopped working as of...
# 33   I don't even know if the GS3's have issues wit...
# 37   Great little card.. The only problem that I ha...
# 54   Bought this card for my Galaxy S4 and, after i...
# 59   But since I can't say anything with any certai...
# 61   Gave it 4 stars because I don't know if the on...
# 65   SanDisk makes a lot of claims about this card,...
# 71   Doesn't work in my s2 skyrocket, but works in ...
# 75   I connected with it to my galaxy S4, but every...
# 79   Um, nothing much to really say about it.. The ...
# 83   I should have probably known better.. Everyone...
# 108  I bought this Sandisk 16GB Class 10 to use wit...
# 135  I ordered from this memory card for my Drift G...
# 148  Hard to review this as if the card arrived DOA...
# 153  Within an hour of using the memory card, but i...
# 160  Pro : & & # 9642 ; PriceCons : & # 9642 ; inti...
# 161  I didn't even have this card ever installed in...
# 182  Hello, Great card, a great price.. Plenty of s...
# 183  Even though it says my review is for only the ...
# 194  Fast card while thinking it worked.. Died less...
# 199  randomly erases all my data and asks me to for...
# 202  seems to work good in my gopro have only had i...
# 209  SanDisk told me I needed to send this message ...
# 216  This card only only lasted two weeks before it...
# 239  I purchased four ( 4 ) items from the amazon a...
# 255  Tried this with its adapter based on DSLR Came...
# 257  Sandiskin quality has failed me.. Moving on, t...
# 263  this card would not show 64 GB until i spent $...
# 292  Died within about 6 months!. Stopped being abl...
# 312  It works just fine like it should.. It never r...
# 320  Could not figure out exactly why this card cra...
# 321  Maybe I got a defective card but this one felt...
# 333  I bought two as a back up for my Gopro Hero 3....
# 343  THIS CARD DIED IN LESS THAN ONE MONTH IN MY SI...
# 351  the unit shows 0 bytes, in a PC, or the phone....
# 354  This card continually unmounted me in my S4.. ...
# 355  I hope you have better luck, it has gotten a l...
# 378  I ordered two 32GB and two more 64Gb versions ...
# 381  The product met my expectations ( I expected i...
# 389  I got this card only a few short months ago, u...
# 390  Don't you even waste your time buying this mem...
# 391  I was really excited when this came out I have...
# 396  I loaded this memory card into my TF700T and c...
# 408  06.NOV.2012 -. Bought the card. 12. JAN. 2014 ...
# 426  Lasted for about 8 months of daily use in my A...
# 430  I use it for my galaxy s4 and this card crashe...

# %%
augmented_val_data_1 = val_data[["augmented_text_1", "overall", "sentiment"]]
augmented_val_data_1.rename(columns={"augmented_text_1": "reviewText"}, inplace=True)
augmented_val_data_2 = val_data[["augmented_text_2", "overall", "sentiment"]]
augmented_val_data_2.rename(columns={"augmented_text_2": "reviewText"}, inplace=True)
augmented_valing_data = pd.concat([augmented_val_data_1, augmented_val_data_2], ignore_index=True)
# Out:
# /var/folders/07/q6zkzh1x581gwdf4lh62vw680000gn/T/ipykernel_40151/2659275158.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   augmented_val_data_1.rename(columns={"augmented_text_1": "reviewText"}, inplace=True)
# /var/folders/07/q6zkzh1x581gwdf4lh62vw680000gn/T/ipykernel_40151/2659275158.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   augmented_val_data_2.rename(columns={"augmented_text_2": "reviewText"}, inplace=True)

# %%
augmented_valing_data
# Out:
#                                            reviewText  overall  sentiment
# 0   It's the exact wrong one because I thought I w...      3.0          0
# 1   UPDATE:This card stopped working as of late Fe...      1.0          0
# 2   I do not know if the older GS3's have issues w...      3.0          0
# 3   Great little card..  The only problem I have e...      3.0          0
# 4   Bought this card for my Galaxy S4 and after in...      2.0          0
# ..                                                ...      ...        ...
# 89  I was really excited when this came out I have...      3.0          0
# 90  I loaded this memory card into my TF700T and c...      2.0          0
# 91  06.NOV.2012 -. Bought the card. 12. JAN. 2014 ...      1.0          0
# 92  Lasted for about 8 months of daily use in my A...      3.0          0
# 93  I use it for my galaxy s4 and this card crashe...      3.0          0
#
# [94 rows x 3 columns]

# %%
augmented_valing_data.to_csv("data_v2/Aug_Val_RandomInsertion.csv", index=False)
